# %% [markdown]
# ##Ship Object Size Graph

# %% [markdown]
# Train Data
# <br/>Validation Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
from glob import glob
from termcolor import colored
import matplotlib.pyplot as plt

# %% [markdown]
# #Train Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
dry_cargo_ship_object_size = list(train_dry_cargo_ship_polygon_df['object size'])
liquid_cargo_ship_object_size = list(train_liquid_cargo_ship_polygon_df['object size'])
motorboat_object_size = list(train_motorboat_polygon_df['object size'])
fishing_boat_object_size = list(train_fishing_boat_polygon_df['object size'])
tug_boat_object_size = list(train_tug_boat_polygon_df['object size'])
engineering_ship_object_size = list(train_engineering_ship_polygon_df['object size'])
warship_object_size = list(train_warship_polygon_df['object size'])
passenger_ship_object_size = list(train_passenger_ship_polygon_df['object size'])
other_ship_object_size = list(train_other_ship_polygon_df['object size'])

average_dry_cargo_ship_object_size = np.mean(dry_cargo_ship_object_size)
average_liquid_cargo_ship_object_size = np.mean(liquid_cargo_ship_object_size)
average_motorboat_object_size = np.mean(motorboat_object_size)
average_fishing_boat_object_size = np.mean(fishing_boat_object_size)
average_tug_boat_object_size = np.mean(tug_boat_object_size)
average_engineering_ship_object_size = np.mean(engineering_ship_object_size)
average_warship_object_size = np.mean(warship_object_size)
average_passenger_ship_object_size = np.mean(passenger_ship_object_size)
average_other_ship_object_size = np.mean(other_ship_object_size)

ship_class_object_size_list = sum([dry_cargo_ship_object_size, liquid_cargo_ship_object_size, motorboat_object_size,
                                      fishing_boat_object_size, tug_boat_object_size, engineering_ship_object_size,
                                      warship_object_size,passenger_ship_object_size, other_ship_object_size], [])

xs = ['Dry Cargo Ship', 'Liquid Cargo Ship', 'Motorboat', 'Fishing Boat',
      'Tugboat', 'Engineering Ship', 'Warship', 'Passenger Ship', 'other-ship']
ys = [average_dry_cargo_ship_object_size, average_liquid_cargo_ship_object_size, average_motorboat_object_size,
      average_fishing_boat_object_size, average_tug_boat_object_size, average_engineering_ship_object_size,
      average_warship_object_size,average_passenger_ship_object_size, average_other_ship_object_size]

plt.figure(figsize=(12, 4))
plt.title('Ship Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_ship_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(ship_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(ship_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(ship_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(ship_class_object_size_list), 2)}")

percentile25 = np.percentile(ship_class_object_size_list, 25); percentile50 = np.percentile(ship_class_object_size_list, 50)
percentile75 = np.percentile(ship_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

dry_cargo_ship_object_size = list(train_dry_cargo_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(dry_cargo_ship_object_size, range=(0,40000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(dry_cargo_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Dry Cargo Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_dry_cargo_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(dry_cargo_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(dry_cargo_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(dry_cargo_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(dry_cargo_ship_object_size), 2)}")

percentile25 = np.percentile(dry_cargo_ship_object_size, 25); percentile50 = np.percentile(dry_cargo_ship_object_size, 50)
percentile75 = np.percentile(dry_cargo_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

liquid_cargo_ship_object_size = list(train_liquid_cargo_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(liquid_cargo_ship_object_size, range=(0,35000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(liquid_cargo_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Liquid Cargo Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_liquid_cargo_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(liquid_cargo_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(liquid_cargo_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(liquid_cargo_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(liquid_cargo_ship_object_size), 2)}")

percentile25 = np.percentile(liquid_cargo_ship_object_size, 25); percentile50 = np.percentile(liquid_cargo_ship_object_size, 50)
percentile75 = np.percentile(liquid_cargo_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

motorboat_object_size = list(train_motorboat_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(motorboat_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(motorboat_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Motorboat Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_motorboat_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(motorboat_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(motorboat_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(motorboat_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(motorboat_object_size), 2)}")

percentile25 = np.percentile(motorboat_object_size, 25); percentile50 = np.percentile(motorboat_object_size, 50)
percentile75 = np.percentile(motorboat_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

fishing_boat_object_size = list(train_fishing_boat_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(fishing_boat_object_size, range=(0,4000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(fishing_boat_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Fishing Boat Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_fishing_boat_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(fishing_boat_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(fishing_boat_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(fishing_boat_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(fishing_boat_object_size), 2)}")

percentile25 = np.percentile(fishing_boat_object_size, 25); percentile50 = np.percentile(fishing_boat_object_size, 50)
percentile75 = np.percentile(fishing_boat_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

tug_boat_object_size = list(train_tug_boat_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(tug_boat_object_size, range=(0,3500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(tug_boat_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Tugboat Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_tug_boat_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(tug_boat_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(tug_boat_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(tug_boat_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(tug_boat_object_size), 2)}")

percentile25 = np.percentile(tug_boat_object_size, 25); percentile50 = np.percentile(tug_boat_object_size, 50)
percentile75 = np.percentile(tug_boat_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

engineering_ship_object_size = list(train_engineering_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(engineering_ship_object_size, range=(0,12000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(engineering_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Engineering Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_engineering_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(engineering_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(engineering_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(engineering_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(engineering_ship_object_size), 2)}")

percentile25 = np.percentile(engineering_ship_object_size, 25); percentile50 = np.percentile(engineering_ship_object_size, 50)
percentile75 = np.percentile(engineering_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

warship_object_size = list(train_warship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(warship_object_size, range=(0,30000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(warship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Warship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_warship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(warship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(warship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(warship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(warship_object_size), 2)}")

percentile25 = np.percentile(warship_object_size, 25); percentile50 = np.percentile(warship_object_size, 50)
percentile75 = np.percentile(warship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

passenger_ship_object_size = list(train_passenger_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(passenger_ship_object_size, range=(0,50000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(passenger_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Passenger Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_passenger_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(passenger_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(passenger_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(passenger_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(passenger_ship_object_size), 2)}")

percentile25 = np.percentile(passenger_ship_object_size, 25); percentile50 = np.percentile(passenger_ship_object_size, 50)
percentile75 = np.percentile(passenger_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

other_ship_object_size = list(train_other_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(other_ship_object_size, range=(0,8000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(other_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Other Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_other_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(other_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(other_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(other_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(other_ship_object_size), 2)}")

percentile25 = np.percentile(other_ship_object_size, 25); percentile50 = np.percentile(other_ship_object_size, 50)
percentile75 = np.percentile(other_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 122407.5  Minimum: 0.5  Average: 1856.52  Standard Deviation: 4036.63
# Q1:228.0  Q2:650.0  Q3:1700.0  IQR:1472.0  Q4:3908.0
# Maximum: 122407.5  Minimum: 65.0  Average: 3671.86  Standard Deviation: 6055.4
# Q1:845.75  Q2:1577.0  Q3:3646.0  IQR:2800.25  Q4:7846.38
# Maximum: 49987.5  Minimum: 104.5  Average: 3412.95  Standard Deviation: 4132.55
# Q1:1296.0  Q2:2175.0  Q3:3363.5  IQR:2067.5  Q4:6464.75
# Maximum: 54441.0  Minimum: 1.0  Average: 208.13  Standard Deviation: 644.95
# Q1:107.62  Q2:159.0  Q3:231.0  IQR:123.38  Q4:416.06
# Maximum: 7595.0  Minimum: 0.5  Average: 573.04  Standard Deviation: 548.68
# Q1:239.0  Q2:406.0  Q3:702.0  IQR:463.0  Q4:1396.5
# Maximum: 2859.0  Minimum: 55.0  Average: 685.31  Standard Deviation: 357.62
# Q1:456.0  Q2:632.5  Q3:833.0  IQR:377.0  Q4:1398.5
# Maximum: 22445.0  Minimum: 181.0  Average: 2201.82  Standard Deviation: 1775.67
# Q1:1121.0  Q2:1804.5  Q3:2803.0  IQR:1682.0  Q4:5326.0
# ...

# %% [markdown]
# #Validation Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
dry_cargo_ship_object_size = list(validation_dry_cargo_ship_polygon_df['object size'])
liquid_cargo_ship_object_size = list(validation_liquid_cargo_ship_polygon_df['object size'])
motorboat_object_size = list(validation_motorboat_polygon_df['object size'])
fishing_boat_object_size = list(validation_fishing_boat_polygon_df['object size'])
tug_boat_object_size = list(validation_tug_boat_polygon_df['object size'])
engineering_ship_object_size = list(validation_engineering_ship_polygon_df['object size'])
warship_object_size = list(validation_warship_polygon_df['object size'])
passenger_ship_object_size = list(validation_passenger_ship_polygon_df['object size'])
other_ship_object_size = list(validation_other_ship_polygon_df['object size'])

average_dry_cargo_ship_object_size = np.mean(dry_cargo_ship_object_size)
average_liquid_cargo_ship_object_size = np.mean(liquid_cargo_ship_object_size)
average_motorboat_object_size = np.mean(motorboat_object_size)
average_fishing_boat_object_size = np.mean(fishing_boat_object_size)
average_tug_boat_object_size = np.mean(tug_boat_object_size)
average_engineering_ship_object_size = np.mean(engineering_ship_object_size)
average_warship_object_size = np.mean(warship_object_size)
average_passenger_ship_object_size = np.mean(passenger_ship_object_size)
average_other_ship_object_size = np.mean(other_ship_object_size)

ship_class_object_size_list = sum([dry_cargo_ship_object_size, liquid_cargo_ship_object_size, motorboat_object_size,
                                      fishing_boat_object_size, tug_boat_object_size, engineering_ship_object_size,
                                      warship_object_size,passenger_ship_object_size, other_ship_object_size], [])

xs = ['Dry Cargo Ship', 'Liquid Cargo Ship', 'Motorboat', 'Fishing Boat',
      'Tugboat', 'Engineering Ship', 'Warship', 'Passenger Ship', 'other-ship']
ys = [average_dry_cargo_ship_object_size, average_liquid_cargo_ship_object_size, average_motorboat_object_size,
      average_fishing_boat_object_size, average_tug_boat_object_size, average_engineering_ship_object_size,
      average_warship_object_size,average_passenger_ship_object_size, average_other_ship_object_size]

plt.figure(figsize=(12, 4))
plt.title('Ship Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_ship_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(ship_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(ship_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(ship_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(ship_class_object_size_list), 2)}")

percentile25 = np.percentile(ship_class_object_size_list, 25); percentile50 = np.percentile(ship_class_object_size_list, 50)
percentile75 = np.percentile(ship_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

dry_cargo_ship_object_size = list(validation_dry_cargo_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(dry_cargo_ship_object_size, range=(0,40000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(dry_cargo_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Dry Cargo Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_dry_cargo_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(dry_cargo_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(dry_cargo_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(dry_cargo_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(dry_cargo_ship_object_size), 2)}")

percentile25 = np.percentile(dry_cargo_ship_object_size, 25); percentile50 = np.percentile(dry_cargo_ship_object_size, 50)
percentile75 = np.percentile(dry_cargo_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

liquid_cargo_ship_object_size = list(validation_liquid_cargo_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(liquid_cargo_ship_object_size, range=(0,35000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(liquid_cargo_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Liquid Cargo Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_liquid_cargo_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(liquid_cargo_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(liquid_cargo_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(liquid_cargo_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(liquid_cargo_ship_object_size), 2)}")

percentile25 = np.percentile(liquid_cargo_ship_object_size, 25); percentile50 = np.percentile(liquid_cargo_ship_object_size, 50)
percentile75 = np.percentile(liquid_cargo_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

motorboat_object_size = list(validation_motorboat_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(motorboat_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(motorboat_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Motorboat Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_motorboat_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(motorboat_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(motorboat_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(motorboat_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(motorboat_object_size), 2)}")

percentile25 = np.percentile(motorboat_object_size, 25); percentile50 = np.percentile(motorboat_object_size, 50)
percentile75 = np.percentile(motorboat_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

fishing_boat_object_size = list(validation_fishing_boat_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(fishing_boat_object_size, range=(0,4000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(fishing_boat_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Fishing Boat Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_fishing_boat_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(fishing_boat_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(fishing_boat_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(fishing_boat_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(fishing_boat_object_size), 2)}")

percentile25 = np.percentile(fishing_boat_object_size, 25); percentile50 = np.percentile(fishing_boat_object_size, 50)
percentile75 = np.percentile(fishing_boat_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

tug_boat_object_size = list(validation_tug_boat_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(tug_boat_object_size, range=(0,3500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(tug_boat_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Tugboat Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_tug_boat_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(tug_boat_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(tug_boat_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(tug_boat_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(tug_boat_object_size), 2)}")

percentile25 = np.percentile(tug_boat_object_size, 25); percentile50 = np.percentile(tug_boat_object_size, 50)
percentile75 = np.percentile(tug_boat_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

engineering_ship_object_size = list(validation_engineering_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(engineering_ship_object_size, range=(0,12000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(engineering_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Engineering Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_engineering_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(engineering_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(engineering_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(engineering_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(engineering_ship_object_size), 2)}")

percentile25 = np.percentile(engineering_ship_object_size, 25); percentile50 = np.percentile(engineering_ship_object_size, 50)
percentile75 = np.percentile(engineering_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

warship_object_size = list(validation_warship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(warship_object_size, range=(0,30000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(warship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Warship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_warship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(warship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(warship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(warship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(warship_object_size), 2)}")

percentile25 = np.percentile(warship_object_size, 25); percentile50 = np.percentile(warship_object_size, 50)
percentile75 = np.percentile(warship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

passenger_ship_object_size = list(validation_passenger_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(passenger_ship_object_size, range=(0,50000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(passenger_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Passenger Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_passenger_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(passenger_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(passenger_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(passenger_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(passenger_ship_object_size), 2)}")

percentile25 = np.percentile(passenger_ship_object_size, 25); percentile50 = np.percentile(passenger_ship_object_size, 50)
percentile75 = np.percentile(passenger_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

other_ship_object_size = list(validation_other_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(other_ship_object_size, range=(0,8000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(other_ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Other Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution(validation_detailed_class_polygon_graph(validation_other_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(other_ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(other_ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(other_ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(other_ship_object_size), 2)}")

percentile25 = np.percentile(other_ship_object_size, 25); percentile50 = np.percentile(other_ship_object_size, 50)
percentile75 = np.percentile(other_ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 64852.0  Minimum: 22.0  Average: 1404.2  Standard Deviation: 2555.34
# Q1:237.0  Q2:597.5  Q3:1620.0  IQR:1383.0  Q4:3694.5
# Maximum: 64852.0  Minimum: 37.5  Average: 2458.36  Standard Deviation: 3693.29
# Q1:735.0  Q2:1481.0  Q3:2544.0  IQR:1809.0  Q4:5257.5
# Maximum: 33499.5  Minimum: 79.0  Average: 3036.56  Standard Deviation: 4254.63
# Q1:763.0  Q2:2114.0  Q3:3418.5  IQR:2655.5  Q4:7401.75
# Maximum: 2821.0  Minimum: 22.0  Average: 259.04  Standard Deviation: 213.77
# Q1:132.0  Q2:200.0  Q3:308.75  IQR:176.75  Q4:573.88
# Maximum: 4719.5  Minimum: 44.65  Average: 550.06  Standard Deviation: 551.24
# Q1:192.0  Q2:362.0  Q3:726.0  IQR:534.0  Q4:1527.0
# Maximum: 2713.5  Minimum: 139.0  Average: 682.7  Standard Deviation: 354.43
# Q1:480.0  Q2:636.5  Q3:818.13  IQR:338.13  Q4:1325.33
# Maximum: 11611.45  Minimum: 171.88  Average: 2474.87  Standard Deviation: 1620.48
# Q1:1183.0  Q2:2275.0  Q3:3336.0  IQR:2153.0  Q4:6565.5
# ...
