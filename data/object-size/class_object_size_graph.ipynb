# %% [markdown]
# ##Class Object Size Graph

# %% [markdown]
# Train Data
# <br/>Validation Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
from glob import glob
from termcolor import colored
import matplotlib.pyplot as plt

# %% [markdown]
# #Train Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
vehicle_object_size = list(train_vehicle_polygon_df['object size'])
ship_object_size = list(train_ship_polygon_df['object size'])
airplane_object_size = list(train_airplane_polygon_df['object size'])

average_ship_object_size = np.mean(ship_object_size)
average_vehicle_object_size = np.mean(vehicle_object_size)
average_airplane_object_size = np.mean(airplane_object_size)

class_object_size_list = sum([vehicle_object_size, ship_object_size, airplane_object_size], [])
xs = ['Vehicle', 'Ship', 'Airplane']
ys = [average_vehicle_object_size, average_ship_object_size, average_airplane_object_size]

plt.figure(figsize=(12, 4))
plt.title('Class Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_class_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(class_object_size_list), 2)}")

percentile25 = np.percentile(class_object_size_list, 25); percentile50 = np.percentile(class_object_size_list, 50)
percentile75 = np.percentile(class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 122407.5  Minimum: 0.0  Average: 565.5  Standard Deviation: 1673.73
# Q1:128.0  Q2:157.0  Q3:207.0  IQR:79.0  Q4:325.5

# %%
vehicle_object_size = list(train_vehicle_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(vehicle_object_size, range=(0,1000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(vehicle_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Vehicle Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_vehicle_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(vehicle_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(vehicle_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(vehicle_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(vehicle_object_size), 2)}")

percentile25 = np.percentile(vehicle_object_size, 25); percentile50 = np.percentile(vehicle_object_size, 50)
percentile75 = np.percentile(vehicle_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

ship_object_size = list(train_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(ship_object_size, range=(0,30000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(ship_object_size), 2)}")

percentile25 = np.percentile(ship_object_size, 25); percentile50 = np.percentile(ship_object_size, 50)
percentile75 = np.percentile(ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

airplane_object_size = list(train_airplane_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(airplane_object_size, range=(0,20000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(airplane_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Airplane Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_airplane_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(airplane_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(airplane_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(airplane_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(airplane_object_size), 2)}")

percentile25 = np.percentile(airplane_object_size, 25); percentile50 = np.percentile(airplane_object_size, 50)
percentile75 = np.percentile(airplane_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 39966.43  Minimum: 0.0  Average: 161.74  Standard Deviation: 114.55
# Q1:124.0  Q2:149.0  Q3:179.0  IQR:55.0  Q4:261.5
# Maximum: 122407.5  Minimum: 0.5  Average: 1857.28  Standard Deviation: 4041.19
# Q1:228.0  Q2:650.0  Q3:1700.0  IQR:1472.0  Q4:3908.0
# Maximum: 25923.0  Minimum: 0.0  Average: 3454.5  Standard Deviation: 2486.96
# Q1:1935.0  Q2:2346.25  Q3:5353.0  IQR:3418.0  Q4:10480.0

# %%
dump_truck_object_size = list(train_dump_truck_polygon_df['object size'])
cargo_truck_object_size = list(train_cargo_truck_polygon_df['object size'])
truck_tractor_object_size = list(train_truck_tractor_polygon_df['object size'])
tractor_object_size = list(train_tractor_polygon_df['object size'])
excavator_object_size = list(train_excavator_polygon_df['object size'])
trailer_object_size = list(train_trailer_polygon_df['object size'])
van_object_size = list(train_van_polygon_df['object size'])
small_car_object_size = list(train_small_car_polygon_df['object size'])
bus_object_size = list(train_bus_polygon_df['object size'])
other_vehicle_object_size = list(train_other_vehicle_polygon_df['object size'])

average_dump_truck_object_size = np.mean(dump_truck_object_size)
average_cargo_truck_object_size = np.mean(cargo_truck_object_size)
average_truck_tractor_object_size = np.mean(truck_tractor_object_size)
average_tractor_object_size = np.mean(tractor_object_size)
average_excavator_object_size = np.mean(excavator_object_size)
average_trailer_object_size = np.mean(trailer_object_size)
average_van_object_size = np.mean(van_object_size)
average_small_car_object_size = np.mean(small_car_object_size)
average_bus_object_size = np.mean(bus_object_size)
average_other_vehicle_object_size = np.mean(other_vehicle_object_size)

vehicle_class_object_size_list = sum([dump_truck_object_size, cargo_truck_object_size, truck_tractor_object_size,
                                      tractor_object_size, excavator_object_size, trailer_object_size, van_object_size,
                                      small_car_object_size, bus_object_size, other_vehicle_object_size], [])

xs = ['Dump Truck', 'Cargo Truck', 'Truck Tractor', 'Tractor','Excavator',
      'Trailer', 'Van', 'Small Car', 'Bus', 'other-vehicle']
ys = [average_dump_truck_object_size, average_cargo_truck_object_size, average_truck_tractor_object_size,
      average_tractor_object_size, average_excavator_object_size, average_trailer_object_size,
      average_van_object_size, average_small_car_object_size, average_bus_object_size, average_other_vehicle_object_size]

plt.figure(figsize=(12, 4))
plt.title('Vehicle Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_vehicle_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(vehicle_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(vehicle_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(vehicle_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(vehicle_class_object_size_list), 2)}")

percentile25 = np.percentile(vehicle_class_object_size_list, 25); percentile50 = np.percentile(vehicle_class_object_size_list, 50)
percentile75 = np.percentile(vehicle_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

dry_cargo_ship_object_size = list(train_dry_cargo_ship_polygon_df['object size'])
liquid_cargo_ship_object_size = list(train_liquid_cargo_ship_polygon_df['object size'])
motorboat_object_size = list(train_motorboat_polygon_df['object size'])
fishing_boat_object_size = list(train_fishing_boat_polygon_df['object size'])
tug_boat_object_size = list(train_tug_boat_polygon_df['object size'])
engineering_ship_object_size = list(train_engineering_ship_polygon_df['object size'])
warship_object_size = list(train_warship_polygon_df['object size'])
passenger_ship_object_size = list(train_passenger_ship_polygon_df['object size'])
other_ship_object_size = list(train_other_ship_polygon_df['object size'])

average_dry_cargo_ship_object_size = np.mean(dry_cargo_ship_object_size)
average_liquid_cargo_ship_object_size = np.mean(liquid_cargo_ship_object_size)
average_motorboat_object_size = np.mean(motorboat_object_size)
average_fishing_boat_object_size = np.mean(fishing_boat_object_size)
average_tug_boat_object_size = np.mean(tug_boat_object_size)
average_engineering_ship_object_size = np.mean(engineering_ship_object_size)
average_warship_object_size = np.mean(warship_object_size)
average_passenger_ship_object_size = np.mean(passenger_ship_object_size)
average_other_ship_object_size = np.mean(other_ship_object_size)

ship_class_object_size_list = sum([dry_cargo_ship_object_size, liquid_cargo_ship_object_size, motorboat_object_size,
                                      fishing_boat_object_size, tug_boat_object_size, engineering_ship_object_size,
                                      warship_object_size,passenger_ship_object_size, other_ship_object_size], [])

xs = ['Dry Cargo Ship', 'Liquid Cargo Ship', 'Motorboat', 'Fishing Boat',
      'Tugboat', 'Engineering Ship', 'Warship', 'Passenger Ship', 'other-ship']
ys = [average_dry_cargo_ship_object_size, average_liquid_cargo_ship_object_size, average_motorboat_object_size,
      average_fishing_boat_object_size, average_tug_boat_object_size, average_engineering_ship_object_size,
      average_warship_object_size,average_passenger_ship_object_size, average_other_ship_object_size]

plt.figure(figsize=(12, 4))
plt.title('Ship Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_ship_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(ship_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(ship_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(ship_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(ship_class_object_size_list), 2)}")

percentile25 = np.percentile(ship_class_object_size_list, 25); percentile50 = np.percentile(ship_class_object_size_list, 50)
percentile75 = np.percentile(ship_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a220_object_size = list(train_a220_polygon_df['object size'])
a321_object_size = list(train_a321_polygon_df['object size'])
a330_object_size = list(train_a330_polygon_df['object size'])
a350_object_size = list(train_a350_polygon_df['object size'])
boeing737_object_size = list(train_boeing737_polygon_df['object size'])
boeing747_object_size = list(train_boeing747_polygon_df['object size'])
boeing777_object_size = list(train_boeing777_polygon_df['object size'])
boeing787_object_size = list(train_boeing787_polygon_df['object size'])
arj21_object_size = list(train_arj21_polygon_df['object size'])
c919_object_size = list(train_c919_polygon_df['object size'])
other_airplane_object_size = list(train_other_airplane_polygon_df['object size'])

average_a220_object_size = np.mean(a220_object_size)
average_a321_object_size = np.mean(a321_object_size)
average_a330_object_size = np.mean(a330_object_size)
average_a350_object_size = np.mean(a350_object_size)
average_boeing737_object_size = np.mean(boeing737_object_size)
average_boeing747_object_size = np.mean(boeing747_object_size)
average_boeing777_object_size = np.mean(boeing777_object_size)
average_boeing787_object_size = np.mean(boeing787_object_size)
average_arj21_object_size = np.mean(arj21_object_size)
average_c919_object_size = np.mean(c919_object_size)
average_other_airplane_object_size = np.mean(other_airplane_object_size)

airplane_class_object_size_list = sum([a220_object_size, a321_object_size, a330_object_size, a350_object_size,
                                      boeing737_object_size, boeing747_object_size, boeing777_object_size, boeing787_object_size,
                                       arj21_object_size, c919_object_size, other_airplane_object_size], [])

xs = ['A220', 'A321', 'A330',  'A350', 'Boeing737', 'Boeing747', 'Boeing777', 'Boeing787', 'ARJ21', 'C919', 'other-airplane']
ys = [average_a220_object_size, average_a321_object_size, average_a330_object_size, average_a350_object_size,
      average_boeing737_object_size, average_boeing747_object_size, average_boeing777_object_size,
      average_boeing787_object_size, average_arj21_object_size, average_c919_object_size, average_other_airplane_object_size]

plt.figure(figsize=(12, 4))
plt.title('Airplane Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_airplane_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(airplane_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(airplane_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(airplane_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(airplane_class_object_size_list), 2)}")

percentile25 = np.percentile(airplane_class_object_size_list, 25); percentile50 = np.percentile(airplane_class_object_size_list, 50)
percentile75 = np.percentile(airplane_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 39966.43  Minimum: 0.0  Average: 161.74  Standard Deviation: 114.55
# Q1:124.0  Q2:149.0  Q3:179.0  IQR:55.0  Q4:261.5
# Maximum: 122407.5  Minimum: 0.5  Average: 1856.52  Standard Deviation: 4036.63
# Q1:228.0  Q2:650.0  Q3:1700.0  IQR:1472.0  Q4:3908.0
# Maximum: 25923.0  Minimum: 0.0  Average: 3454.5  Standard Deviation: 2486.96
# Q1:1935.0  Q2:2346.25  Q3:5353.0  IQR:3418.0  Q4:10480.0

# %% [markdown]
# #Validation Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
vehicle_object_size = list(validation_vehicle_polygon_df['object size'])
ship_object_size = list(validation_ship_polygon_df['object size'])
airplane_object_size = list(validation_airplane_polygon_df['object size'])

average_ship_object_size = np.mean(ship_object_size)
average_vehicle_object_size = np.mean(vehicle_object_size)
average_airplane_object_size = np.mean(airplane_object_size)

class_object_size_list = sum([vehicle_object_size, ship_object_size, airplane_object_size], [])
xs = ['Vehicle', 'Ship', 'Airplane']
ys = [average_vehicle_object_size, average_ship_object_size, average_airplane_object_size]

plt.figure(figsize=(12, 4))
plt.title('Class Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_class_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(class_object_size_list), 2)}")

percentile25 = np.percentile(class_object_size_list, 25); percentile50 = np.percentile(class_object_size_list, 50)
percentile75 = np.percentile(class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 74455.01  Minimum: 21.0  Average: 600.17  Standard Deviation: 1761.24
# Q1:115.0  Q2:148.5  Q3:218.0  IQR:103.0  Q4:372.5

# %%
vehicle_object_size = list(validation_vehicle_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(vehicle_object_size, range=(0,1000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(vehicle_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Vehicle Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_vehicle_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(vehicle_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(vehicle_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(vehicle_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(vehicle_object_size), 2)}")

percentile25 = np.percentile(vehicle_object_size, 25); percentile50 = np.percentile(vehicle_object_size, 50)
percentile75 = np.percentile(vehicle_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

ship_object_size = list(validation_ship_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(ship_object_size, range=(0,30000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(ship_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Ship Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_ship_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(ship_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(ship_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(ship_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(ship_object_size), 2)}")

percentile25 = np.percentile(ship_object_size, 25); percentile50 = np.percentile(ship_object_size, 50)
percentile75 = np.percentile(ship_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

airplane_object_size = list(validation_airplane_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(airplane_object_size, range=(0,20000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(airplane_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Airplane Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_airplane_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(airplane_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(airplane_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(airplane_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(airplane_object_size), 2)}")

percentile25 = np.percentile(airplane_object_size, 25); percentile50 = np.percentile(airplane_object_size, 50)
percentile75 = np.percentile(airplane_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 11038.5  Minimum: 21.0  Average: 150.42  Standard Deviation: 90.21
# Q1:109.0  Q2:136.0  Q3:167.5  IQR:58.5  Q4:255.25
# Maximum: 64852.0  Minimum: 22.0  Average: 1404.2  Standard Deviation: 2555.34
# Q1:237.0  Q2:597.5  Q3:1620.0  IQR:1383.0  Q4:3694.5
# Maximum: 74455.01  Minimum: 80.18  Average: 3927.99  Standard Deviation: 3948.14
# Q1:1873.0  Q2:2362.5  Q3:5216.5  IQR:3343.5  Q4:10231.75

# %%
dump_truck_object_size = list(validation_dump_truck_polygon_df['object size'])
cargo_truck_object_size = list(validation_cargo_truck_polygon_df['object size'])
truck_tractor_object_size = list(validation_truck_tractor_polygon_df['object size'])
tractor_object_size = list(validation_tractor_polygon_df['object size'])
excavator_object_size = list(validation_excavator_polygon_df['object size'])
trailer_object_size = list(validation_trailer_polygon_df['object size'])
van_object_size = list(validation_van_polygon_df['object size'])
small_car_object_size = list(validation_small_car_polygon_df['object size'])
bus_object_size = list(validation_bus_polygon_df['object size'])
other_vehicle_object_size = list(validation_other_vehicle_polygon_df['object size'])

average_dump_truck_object_size = np.mean(dump_truck_object_size)
average_cargo_truck_object_size = np.mean(cargo_truck_object_size)
average_truck_tractor_object_size = np.mean(truck_tractor_object_size)
average_tractor_object_size = np.mean(tractor_object_size)
average_excavator_object_size = np.mean(excavator_object_size)
average_trailer_object_size = np.mean(trailer_object_size)
average_van_object_size = np.mean(van_object_size)
average_small_car_object_size = np.mean(small_car_object_size)
average_bus_object_size = np.mean(bus_object_size)
average_other_vehicle_object_size = np.mean(other_vehicle_object_size)

vehicle_class_object_size_list = sum([dump_truck_object_size, cargo_truck_object_size, truck_tractor_object_size,
                                      tractor_object_size, excavator_object_size, trailer_object_size, van_object_size,
                                      small_car_object_size, bus_object_size, other_vehicle_object_size], [])

xs = ['Dump Truck', 'Cargo Truck', 'Truck Tractor', 'Tractor','Excavator',
      'Trailer', 'Van', 'Small Car', 'Bus', 'other-vehicle']
ys = [average_dump_truck_object_size, average_cargo_truck_object_size, average_truck_tractor_object_size,
      average_tractor_object_size, average_excavator_object_size, average_trailer_object_size,
      average_van_object_size, average_small_car_object_size, average_bus_object_size, average_other_vehicle_object_size]

plt.figure(figsize=(12, 4))
plt.title('Vehicle Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_vehicle_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(vehicle_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(vehicle_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(vehicle_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(vehicle_class_object_size_list), 2)}")

percentile25 = np.percentile(vehicle_class_object_size_list, 25); percentile50 = np.percentile(vehicle_class_object_size_list, 50)
percentile75 = np.percentile(vehicle_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

dry_cargo_ship_object_size = list(validation_dry_cargo_ship_polygon_df['object size'])
liquid_cargo_ship_object_size = list(validation_liquid_cargo_ship_polygon_df['object size'])
motorboat_object_size = list(validation_motorboat_polygon_df['object size'])
fishing_boat_object_size = list(validation_fishing_boat_polygon_df['object size'])
tug_boat_object_size = list(validation_tug_boat_polygon_df['object size'])
engineering_ship_object_size = list(validation_engineering_ship_polygon_df['object size'])
warship_object_size = list(validation_warship_polygon_df['object size'])
passenger_ship_object_size = list(validation_passenger_ship_polygon_df['object size'])
other_ship_object_size = list(validation_other_ship_polygon_df['object size'])

average_dry_cargo_ship_object_size = np.mean(dry_cargo_ship_object_size)
average_liquid_cargo_ship_object_size = np.mean(liquid_cargo_ship_object_size)
average_motorboat_object_size = np.mean(motorboat_object_size)
average_fishing_boat_object_size = np.mean(fishing_boat_object_size)
average_tug_boat_object_size = np.mean(tug_boat_object_size)
average_engineering_ship_object_size = np.mean(engineering_ship_object_size)
average_warship_object_size = np.mean(warship_object_size)
average_passenger_ship_object_size = np.mean(passenger_ship_object_size)
average_other_ship_object_size = np.mean(other_ship_object_size)

ship_class_object_size_list = sum([dry_cargo_ship_object_size, liquid_cargo_ship_object_size, motorboat_object_size,
                                      fishing_boat_object_size, tug_boat_object_size, engineering_ship_object_size,
                                      warship_object_size,passenger_ship_object_size, other_ship_object_size], [])

xs = ['Dry Cargo Ship', 'Liquid Cargo Ship', 'Motorboat', 'Fishing Boat',
      'Tugboat', 'Engineering Ship', 'Warship', 'Passenger Ship', 'other-ship']
ys = [average_dry_cargo_ship_object_size, average_liquid_cargo_ship_object_size, average_motorboat_object_size,
      average_fishing_boat_object_size, average_tug_boat_object_size, average_engineering_ship_object_size,
      average_warship_object_size,average_passenger_ship_object_size, average_other_ship_object_size]

plt.figure(figsize=(12, 4))
plt.title('Ship Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_ship_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(ship_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(ship_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(ship_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(ship_class_object_size_list), 2)}")

percentile25 = np.percentile(ship_class_object_size_list, 25); percentile50 = np.percentile(ship_class_object_size_list, 50)
percentile75 = np.percentile(ship_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a220_object_size = list(validation_a220_polygon_df['object size'])
a321_object_size = list(validation_a321_polygon_df['object size'])
a330_object_size = list(validation_a330_polygon_df['object size'])
a350_object_size = list(validation_a350_polygon_df['object size'])
boeing737_object_size = list(validation_boeing737_polygon_df['object size'])
boeing747_object_size = list(validation_boeing747_polygon_df['object size'])
boeing777_object_size = list(validation_boeing777_polygon_df['object size'])
boeing787_object_size = list(validation_boeing787_polygon_df['object size'])
arj21_object_size = list(validation_arj21_polygon_df['object size'])
c919_object_size = list(validation_c919_polygon_df['object size'])
other_airplane_object_size = list(validation_other_airplane_polygon_df['object size'])

average_a220_object_size = np.mean(a220_object_size)
average_a321_object_size = np.mean(a321_object_size)
average_a330_object_size = np.mean(a330_object_size)
average_a350_object_size = np.mean(a350_object_size)
average_boeing737_object_size = np.mean(boeing737_object_size)
average_boeing747_object_size = np.mean(boeing747_object_size)
average_boeing777_object_size = np.mean(boeing777_object_size)
average_boeing787_object_size = np.mean(boeing787_object_size)
average_arj21_object_size = np.mean(arj21_object_size)
average_c919_object_size = np.mean(c919_object_size)
average_other_airplane_object_size = np.mean(other_airplane_object_size)

airplane_class_object_size_list = sum([a220_object_size, a321_object_size, a330_object_size, a350_object_size,
                                      boeing737_object_size, boeing747_object_size, boeing777_object_size, boeing787_object_size,
                                       arj21_object_size, c919_object_size, other_airplane_object_size], [])

xs = ['A220', 'A321', 'A330',  'A350', 'Boeing737', 'Boeing747', 'Boeing777', 'Boeing787', 'ARJ21', 'C919', 'other-airplane']
ys = [average_a220_object_size, average_a321_object_size, average_a330_object_size, average_a350_object_size,
      average_boeing737_object_size, average_boeing747_object_size, average_boeing777_object_size,
      average_boeing787_object_size, average_arj21_object_size, average_c919_object_size, average_other_airplane_object_size]

plt.figure(figsize=(12, 4))
plt.title('Airplane Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_airplane_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(airplane_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(airplane_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(airplane_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(airplane_class_object_size_list), 2)}")

percentile25 = np.percentile(airplane_class_object_size_list, 25); percentile50 = np.percentile(airplane_class_object_size_list, 50)
percentile75 = np.percentile(airplane_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 11038.5  Minimum: 21.0  Average: 150.42  Standard Deviation: 90.21
# Q1:109.0  Q2:136.0  Q3:167.5  IQR:58.5  Q4:255.25
# Maximum: 64852.0  Minimum: 22.0  Average: 1404.2  Standard Deviation: 2555.34
# Q1:237.0  Q2:597.5  Q3:1620.0  IQR:1383.0  Q4:3694.5
# Maximum: 74455.01  Minimum: 80.18  Average: 3927.99  Standard Deviation: 3948.14
# Q1:1873.0  Q2:2362.5  Q3:5216.5  IQR:3343.5  Q4:10231.75
