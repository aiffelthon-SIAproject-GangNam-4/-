# %% [markdown]
# ##Airplane Object Size Graph

# %% [markdown]
# Train Data
# <br/>Validation Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
from glob import glob
from termcolor import colored
import matplotlib.pyplot as plt

# %% [markdown]
# #Train Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
a220_object_size = list(train_a220_polygon_df['object size'])
a321_object_size = list(train_a321_polygon_df['object size'])
a330_object_size = list(train_a330_polygon_df['object size'])
a350_object_size = list(train_a350_polygon_df['object size'])
boeing737_object_size = list(train_boeing737_polygon_df['object size'])
boeing747_object_size = list(train_boeing747_polygon_df['object size'])
boeing777_object_size = list(train_boeing777_polygon_df['object size'])
boeing787_object_size = list(train_boeing787_polygon_df['object size'])
arj21_object_size = list(train_arj21_polygon_df['object size'])
c919_object_size = list(train_c919_polygon_df['object size'])
other_airplane_object_size = list(train_other_airplane_polygon_df['object size'])

average_a220_object_size = np.mean(a220_object_size)
average_a321_object_size = np.mean(a321_object_size)
average_a330_object_size = np.mean(a330_object_size)
average_a350_object_size = np.mean(a350_object_size)
average_boeing737_object_size = np.mean(boeing737_object_size)
average_boeing747_object_size = np.mean(boeing747_object_size)
average_boeing777_object_size = np.mean(boeing777_object_size)
average_boeing787_object_size = np.mean(boeing787_object_size)
average_arj21_object_size = np.mean(arj21_object_size)
average_c919_object_size = np.mean(c919_object_size)
average_other_airplane_object_size = np.mean(other_airplane_object_size)

airplane_class_object_size_list = sum([a220_object_size, a321_object_size, a330_object_size, a350_object_size,
                                      boeing737_object_size, boeing747_object_size, boeing777_object_size, boeing787_object_size,
                                       arj21_object_size, c919_object_size, other_airplane_object_size], [])

xs = ['A220', 'A321', 'A330',  'A350', 'Boeing737', 'Boeing747', 'Boeing777', 'Boeing787', 'ARJ21', 'C919', 'other-airplane']
ys = [average_a220_object_size, average_a321_object_size, average_a330_object_size, average_a350_object_size,
      average_boeing737_object_size, average_boeing747_object_size, average_boeing777_object_size,
      average_boeing787_object_size, average_arj21_object_size, average_c919_object_size, average_other_airplane_object_size]

plt.figure(figsize=(12, 4))
plt.title('Airplane Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_airplane_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(airplane_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(airplane_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(airplane_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(airplane_class_object_size_list), 2)}")

percentile25 = np.percentile(airplane_class_object_size_list, 25); percentile50 = np.percentile(airplane_class_object_size_list, 50)
percentile75 = np.percentile(airplane_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a220_object_size = list(train_a220_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a220_object_size, range=(0,7000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a220_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A220 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_a220_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a220_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a220_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a220_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a220_object_size), 2)}")

percentile25 = np.percentile(a220_object_size, 25); percentile50 = np.percentile(a220_object_size, 50)
percentile75 = np.percentile(a220_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a321_object_size = list(train_a321_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a321_object_size, range=(0,8000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a321_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A321 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_a321_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a321_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a321_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a321_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a321_object_size), 2)}")

percentile25 = np.percentile(a321_object_size, 25); percentile50 = np.percentile(a321_object_size, 50)
percentile75 = np.percentile(a321_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a330_object_size = list(train_a330_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a330_object_size, range=(0,18000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a330_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A330 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_a330_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a330_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a330_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a330_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a330_object_size), 2)}")

percentile25 = np.percentile(a330_object_size, 25); percentile50 = np.percentile(a330_object_size, 50)
percentile75 = np.percentile(a330_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a350_object_size = list(train_a350_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a350_object_size, range=(0,28000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a350_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A350 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_a350_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a350_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a350_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a350_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a350_object_size), 2)}")

percentile25 = np.percentile(a350_object_size, 25); percentile50 = np.percentile(a350_object_size, 50)
percentile75 = np.percentile(a350_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing737_object_size = list(train_boeing737_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing737_object_size, range=(0,8000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing737_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing737 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_boeing737_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing737_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing737_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing737_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing737_object_size), 2)}")

percentile25 = np.percentile(boeing737_object_size, 25); percentile50 = np.percentile(boeing737_object_size, 50)
percentile75 = np.percentile(boeing737_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing747_object_size = list(train_boeing747_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing747_object_size, range=(0,23000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing747_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing747 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_boeing747_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing747_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing747_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing747_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing747_object_size), 2)}")

percentile25 = np.percentile(boeing747_object_size, 25); percentile50 = np.percentile(boeing747_object_size, 50)
percentile75 = np.percentile(boeing747_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing777_object_size = list(train_boeing777_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing777_object_size, range=(0,16000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing777_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing777 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_boeing777_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing777_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing777_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing777_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing777_object_size), 2)}")

percentile25 = np.percentile(boeing777_object_size, 25); percentile50 = np.percentile(boeing777_object_size, 50)
percentile75 = np.percentile(boeing777_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing787_object_size = list(train_boeing787_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing787_object_size, range=(0,18000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing787_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing787 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_boeing787_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing787_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing787_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing787_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing787_object_size), 2)}")

percentile25 = np.percentile(boeing787_object_size, 25); percentile50 = np.percentile(boeing787_object_size, 50)
percentile75 = np.percentile(boeing787_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

arj21_object_size = list(train_arj21_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(arj21_object_size, range=(0,4000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(arj21_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('ARJ21 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_arj21_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(arj21_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(arj21_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(arj21_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(arj21_object_size), 2)}")

percentile25 = np.percentile(arj21_object_size, 25); percentile50 = np.percentile(arj21_object_size, 50)
percentile75 = np.percentile(arj21_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

c919_object_size = list(train_c919_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(c919_object_size, range=(0,5000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(c919_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('C919 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_c919_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(c919_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(c919_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(c919_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(c919_object_size), 2)}")

percentile25 = np.percentile(c919_object_size, 25); percentile50 = np.percentile(c919_object_size, 50)
percentile75 = np.percentile(c919_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

other_airplane_object_size = list(train_other_airplane_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(other_airplane_object_size, range=(0,13000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(other_airplane_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Other Airplane Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_other_airplane_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(other_airplane_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(other_airplane_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(other_airplane_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(other_airplane_object_size), 2)}")

percentile25 = np.percentile(other_airplane_object_size, 25); percentile50 = np.percentile(other_airplane_object_size, 50)
percentile75 = np.percentile(other_airplane_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 25923.0  Minimum: 0.0  Average: 3454.5  Standard Deviation: 2486.96
# Q1:1935.0  Q2:2346.25  Q3:5353.0  IQR:3418.0  Q4:10480.0
# Maximum: 8690.0  Minimum: 0.0  Average: 2301.18  Standard Deviation: 677.49
# Q1:2011.0  Q2:2141.5  Q3:2315.0  IQR:304.0  Q4:2771.0
# Maximum: 7542.0  Minimum: 0.0  Average: 2740.04  Standard Deviation: 861.93
# Q1:2367.0  Q2:2504.0  Q3:2707.0  IQR:340.0  Q4:3217.0
# Maximum: 16074.5  Minimum: 2187.5  Average: 6485.37  Standard Deviation: 1824.29
# Q1:5764.0  Q2:6096.0  Q3:6427.0  IQR:663.0  Q4:7421.5
# Maximum: 25923.0  Minimum: 3830.81  Average: 7748.63  Standard Deviation: 2108.88
# Q1:7184.0  Q2:7531.0  Q3:7846.45  IQR:662.45  Q4:8840.12
# Maximum: 6782.5  Minimum: 32.0  Average: 2301.34  Standard Deviation: 640.99
# Q1:2048.0  Q2:2184.0  Q3:2373.5  IQR:325.5  Q4:2861.75
# Maximum: 23005.0  Minimum: 3170.54  Average: 7915.12  Standard Deviation: 2229.76
# Q1:6942.0  Q2:7256.0  Q3:8173.51  IQR:1231.51  Q4:10020.77
# ...

# %% [markdown]
# #Validation Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
a220_object_size = list(validation_a220_polygon_df['object size'])
a321_object_size = list(validation_a321_polygon_df['object size'])
a330_object_size = list(validation_a330_polygon_df['object size'])
a350_object_size = list(validation_a350_polygon_df['object size'])
boeing737_object_size = list(validation_boeing737_polygon_df['object size'])
boeing747_object_size = list(validation_boeing747_polygon_df['object size'])
boeing777_object_size = list(validation_boeing777_polygon_df['object size'])
boeing787_object_size = list(validation_boeing787_polygon_df['object size'])
arj21_object_size = list(validation_arj21_polygon_df['object size'])
c919_object_size = list(validation_c919_polygon_df['object size'])
other_airplane_object_size = list(validation_other_airplane_polygon_df['object size'])

average_a220_object_size = np.mean(a220_object_size)
average_a321_object_size = np.mean(a321_object_size)
average_a330_object_size = np.mean(a330_object_size)
average_a350_object_size = np.mean(a350_object_size)
average_boeing737_object_size = np.mean(boeing737_object_size)
average_boeing747_object_size = np.mean(boeing747_object_size)
average_boeing777_object_size = np.mean(boeing777_object_size)
average_boeing787_object_size = np.mean(boeing787_object_size)
average_arj21_object_size = np.mean(arj21_object_size)
average_c919_object_size = np.mean(c919_object_size)
average_other_airplane_object_size = np.mean(other_airplane_object_size)

airplane_class_object_size_list = sum([a220_object_size, a321_object_size, a330_object_size, a350_object_size,
                                      boeing737_object_size, boeing747_object_size, boeing777_object_size, boeing787_object_size,
                                       arj21_object_size, c919_object_size, other_airplane_object_size], [])

xs = ['A220', 'A321', 'A330',  'A350', 'Boeing737', 'Boeing747', 'Boeing777', 'Boeing787', 'ARJ21', 'C919', 'other-airplane']
ys = [average_a220_object_size, average_a321_object_size, average_a330_object_size, average_a350_object_size,
      average_boeing737_object_size, average_boeing747_object_size, average_boeing777_object_size,
      average_boeing787_object_size, average_arj21_object_size, average_c919_object_size, average_other_airplane_object_size]

plt.figure(figsize=(12, 4))
plt.title('Airplane Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_airplane_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(airplane_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(airplane_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(airplane_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(airplane_class_object_size_list), 2)}")

percentile25 = np.percentile(airplane_class_object_size_list, 25); percentile50 = np.percentile(airplane_class_object_size_list, 50)
percentile75 = np.percentile(airplane_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a220_object_size = list(validation_a220_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a220_object_size, range=(0,7000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a220_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A220 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_a220_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a220_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a220_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a220_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a220_object_size), 2)}")

percentile25 = np.percentile(a220_object_size, 25); percentile50 = np.percentile(a220_object_size, 50)
percentile75 = np.percentile(a220_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a321_object_size = list(validation_a321_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a321_object_size, range=(0,8000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a321_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A321 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_a321_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a321_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a321_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a321_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a321_object_size), 2)}")

percentile25 = np.percentile(a321_object_size, 25); percentile50 = np.percentile(a321_object_size, 50)
percentile75 = np.percentile(a321_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a330_object_size = list(validation_a330_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a330_object_size, range=(0,18000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a330_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A330 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_a330_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a330_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a330_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a330_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a330_object_size), 2)}")

percentile25 = np.percentile(a330_object_size, 25); percentile50 = np.percentile(a330_object_size, 50)
percentile75 = np.percentile(a330_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

a350_object_size = list(validation_a350_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(a350_object_size, range=(0,28000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(a350_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('A350 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_a350_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(a350_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(a350_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(a350_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(a350_object_size), 2)}")

percentile25 = np.percentile(a350_object_size, 25); percentile50 = np.percentile(a350_object_size, 50)
percentile75 = np.percentile(a350_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing737_object_size = list(validation_boeing737_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing737_object_size, range=(0,8000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing737_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing737 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_boeing737_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing737_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing737_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing737_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing737_object_size), 2)}")

percentile25 = np.percentile(boeing737_object_size, 25); percentile50 = np.percentile(boeing737_object_size, 50)
percentile75 = np.percentile(boeing737_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing747_object_size = list(validation_boeing747_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing747_object_size, range=(0,23000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing747_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing747 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_boeing747_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing747_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing747_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing747_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing747_object_size), 2)}")

percentile25 = np.percentile(boeing747_object_size, 25); percentile50 = np.percentile(boeing747_object_size, 50)
percentile75 = np.percentile(boeing747_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing777_object_size = list(validation_boeing777_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing777_object_size, range=(0,16000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing777_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing777 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_boeing777_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing777_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing777_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing777_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing777_object_size), 2)}")

percentile25 = np.percentile(boeing777_object_size, 25); percentile50 = np.percentile(boeing777_object_size, 50)
percentile75 = np.percentile(boeing777_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

boeing787_object_size = list(validation_boeing787_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(boeing787_object_size, range=(0,18000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(boeing787_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Boeing787 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_boeing787_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(boeing787_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(boeing787_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(boeing787_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(boeing787_object_size), 2)}")

percentile25 = np.percentile(boeing787_object_size, 25); percentile50 = np.percentile(boeing787_object_size, 50)
percentile75 = np.percentile(boeing787_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

arj21_object_size = list(validation_arj21_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(arj21_object_size, range=(0,4000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(arj21_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('ARJ21 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_arj21_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(arj21_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(arj21_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(arj21_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(arj21_object_size), 2)}")

percentile25 = np.percentile(arj21_object_size, 25); percentile50 = np.percentile(arj21_object_size, 50)
percentile75 = np.percentile(arj21_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

c919_object_size = list(validation_c919_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(c919_object_size, range=(0,5000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(c919_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('C919 Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_c919_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(c919_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(c919_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(c919_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(c919_object_size), 2)}")

percentile25 = np.percentile(c919_object_size, 25); percentile50 = np.percentile(c919_object_size, 50)
percentile75 = np.percentile(c919_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

other_airplane_object_size = list(validation_other_airplane_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(other_airplane_object_size, range=(0,13000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(other_airplane_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Other Airplane Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_other_airplane_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(other_airplane_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(other_airplane_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(other_airplane_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(other_airplane_object_size), 2)}")

percentile25 = np.percentile(other_airplane_object_size, 25); percentile50 = np.percentile(other_airplane_object_size, 50)
percentile75 = np.percentile(other_airplane_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 74455.01  Minimum: 80.18  Average: 3927.99  Standard Deviation: 3948.14
# Q1:1873.0  Q2:2362.5  Q3:5216.5  IQR:3343.5  Q4:10231.75
# Maximum: 19495.0  Minimum: 80.18  Average: 2605.72  Standard Deviation: 1324.53
# Q1:1984.5  Q2:2185.5  Q3:2476.0  IQR:491.5  Q4:3213.25
# Maximum: 7320.0  Minimum: 235.0  Average: 2850.64  Standard Deviation: 1162.61
# Q1:2339.5  Q2:2497.0  Q3:2769.0  IQR:429.5  Q4:3413.25
# Maximum: 56850.01  Minimum: 149.0  Average: 9342.58  Standard Deviation: 5395.85
# Q1:5978.0  Q2:6500.0  Q3:12985.0  IQR:7007.0  Q4:23495.5
# Maximum: 53815.26  Minimum: 143.5  Average: 11120.0  Standard Deviation: 5811.43
# Q1:7360.5  Q2:8547.5  Q3:15367.5  IQR:8007.0  Q4:27378.0
# Maximum: 19138.88  Minimum: 110.5  Average: 2677.4  Standard Deviation: 1282.9
# Q1:2092.0  Q2:2250.0  Q3:2492.0  IQR:400.0  Q4:3092.0
# Maximum: 74455.01  Minimum: 251.0  Average: 9526.36  Standard Deviation: 5984.41
# Q1:7009.5  Q2:7926.0  Q3:9338.12  IQR:2328.62  Q4:12831.06
# ...
