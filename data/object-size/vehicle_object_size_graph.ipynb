# %% [markdown]
# ##Vehicle Object Size Graph

# %% [markdown]
# Train Data
# <br/>Validation Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
from glob import glob
from termcolor import colored
import matplotlib.pyplot as plt

# %% [markdown]
# #Train Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
dump_truck_object_size = list(train_dump_truck_polygon_df['object size'])
cargo_truck_object_size = list(train_cargo_truck_polygon_df['object size'])
truck_tractor_object_size = list(train_truck_tractor_polygon_df['object size'])
tractor_object_size = list(train_tractor_polygon_df['object size'])
excavator_object_size = list(train_excavator_polygon_df['object size'])
trailer_object_size = list(train_trailer_polygon_df['object size'])
van_object_size = list(train_van_polygon_df['object size'])
small_car_object_size = list(train_small_car_polygon_df['object size'])
bus_object_size = list(train_bus_polygon_df['object size'])
other_vehicle_object_size = list(train_other_vehicle_polygon_df['object size'])

average_dump_truck_object_size = np.mean(dump_truck_object_size)
average_cargo_truck_object_size = np.mean(cargo_truck_object_size)
average_truck_tractor_object_size = np.mean(truck_tractor_object_size)
average_tractor_object_size = np.mean(tractor_object_size)
average_excavator_object_size = np.mean(excavator_object_size)
average_trailer_object_size = np.mean(trailer_object_size)
average_van_object_size = np.mean(van_object_size)
average_small_car_object_size = np.mean(small_car_object_size)
average_bus_object_size = np.mean(bus_object_size)
average_other_vehicle_object_size = np.mean(other_vehicle_object_size)

vehicle_class_object_size_list = sum([dump_truck_object_size, cargo_truck_object_size, truck_tractor_object_size,
                                      tractor_object_size, excavator_object_size, trailer_object_size, van_object_size,
                                      small_car_object_size, bus_object_size, other_vehicle_object_size], [])

xs = ['Dump Truck', 'Cargo Truck', 'Truck Tractor', 'Tractor','Excavator',
      'Trailer', 'Van', 'Small Car', 'Bus', 'other-vehicle']
ys = [average_dump_truck_object_size, average_cargo_truck_object_size, average_truck_tractor_object_size,
      average_tractor_object_size, average_excavator_object_size, average_trailer_object_size,
      average_van_object_size, average_small_car_object_size, average_bus_object_size, average_other_vehicle_object_size]

plt.figure(figsize=(12, 4))
plt.title('Vehicle Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_class_polygon_graph/train_vehicle_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(vehicle_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(vehicle_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(vehicle_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(vehicle_class_object_size_list), 2)}")

percentile25 = np.percentile(vehicle_class_object_size_list, 25); percentile50 = np.percentile(vehicle_class_object_size_list, 50)
percentile75 = np.percentile(vehicle_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

dump_truck_object_size = list(train_dump_truck_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(dump_truck_object_size, range=(0,800), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(dump_truck_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Dump Truck Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_dump_truck_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(dump_truck_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(dump_truck_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(dump_truck_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(dump_truck_object_size), 2)}")

percentile25 = np.percentile(dump_truck_object_size, 25); percentile50 = np.percentile(dump_truck_object_size, 50)
percentile75 = np.percentile(dump_truck_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

cargo_truck_object_size = list(train_cargo_truck_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(cargo_truck_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(cargo_truck_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Cargo Truck Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_cargo_truck_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(cargo_truck_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(cargo_truck_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(cargo_truck_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(cargo_truck_object_size), 2)}")

percentile25 = np.percentile(cargo_truck_object_size, 25); percentile50 = np.percentile(cargo_truck_object_size, 50)
percentile75 = np.percentile(cargo_truck_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

truck_tractor_object_size = list(train_truck_tractor_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(truck_tractor_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(truck_tractor_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Truck Tractor Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_truck_tractor_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(truck_tractor_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(truck_tractor_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(truck_tractor_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(truck_tractor_object_size), 2)}")

percentile25 = np.percentile(truck_tractor_object_size, 25); percentile50 = np.percentile(truck_tractor_object_size, 50)
percentile75 = np.percentile(truck_tractor_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

tractor_object_size = list(train_tractor_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(tractor_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(tractor_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Tractor Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_tractor_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(tractor_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(tractor_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(tractor_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(tractor_object_size), 2)}")

percentile25 = np.percentile(tractor_object_size, 25); percentile50 = np.percentile(tractor_object_size, 50)
percentile75 = np.percentile(tractor_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

excavator_object_size = list(train_excavator_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(excavator_object_size, range=(0,2000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(excavator_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Excavator Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_excavator_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(excavator_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(excavator_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(excavator_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(excavator_object_size), 2)}")

percentile25 = np.percentile(excavator_object_size, 25); percentile50 = np.percentile(excavator_object_size, 50)
percentile75 = np.percentile(excavator_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

trailer_object_size = list(train_trailer_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(trailer_object_size, range=(0,2000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(trailer_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Trailer Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_trailer_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(trailer_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(trailer_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(trailer_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(trailer_object_size), 2)}")

percentile25 = np.percentile(trailer_object_size, 25); percentile50 = np.percentile(trailer_object_size, 50)
percentile75 = np.percentile(trailer_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

van_object_size = list(train_van_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(van_object_size, range=(0,400), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(van_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Van Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_van_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(van_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(van_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(van_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(van_object_size), 2)}")

percentile25 = np.percentile(van_object_size, 25); percentile50 = np.percentile(van_object_size, 50)
percentile75 = np.percentile(van_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

small_car_object_size = list(train_small_car_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(small_car_object_size, range=(0,400), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(small_car_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Small Car Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_small_car_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(small_car_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(small_car_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(small_car_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(small_car_object_size), 2)}")

percentile25 = np.percentile(small_car_object_size, 25); percentile50 = np.percentile(small_car_object_size, 50)
percentile75 = np.percentile(small_car_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

bus_object_size = list(train_bus_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(bus_object_size, range=(0,1200), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(bus_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Bus Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_bus_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(bus_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(bus_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(bus_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(bus_object_size), 2)}")

percentile25 = np.percentile(bus_object_size, 25); percentile50 = np.percentile(bus_object_size, 50)
percentile75 = np.percentile(bus_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

other_vehicle_object_size = list(train_other_vehicle_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(other_vehicle_object_size, range=(0,1600), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(other_vehicle_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Other Vehicle Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/train_detailed_class_polygon_graph/train_other_vehicle_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(other_vehicle_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(other_vehicle_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(other_vehicle_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(other_vehicle_object_size), 2)}")

percentile25 = np.percentile(other_vehicle_object_size, 25); percentile50 = np.percentile(other_vehicle_object_size, 50)
percentile75 = np.percentile(other_vehicle_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 39966.43  Minimum: 0.0  Average: 161.74  Standard Deviation: 114.55
# Q1:124.0  Q2:149.0  Q3:179.0  IQR:55.0  Q4:261.5
# Maximum: 9803.0  Minimum: 0.0  Average: 203.9  Standard Deviation: 92.1
# Q1:161.5  Q2:194.0  Q3:231.0  IQR:69.5  Q4:335.25
# Maximum: 24156.0  Minimum: 0.0  Average: 357.92  Standard Deviation: 313.15
# Q1:226.5  Q2:330.0  Q3:445.0  IQR:218.5  Q4:772.75
# Maximum: 1357.0  Minimum: 56.0  Average: 246.78  Standard Deviation: 161.96
# Q1:152.25  Q2:184.5  Q3:298.75  IQR:146.5  Q4:518.5
# Maximum: 1258.5  Minimum: 49.66  Average: 292.09  Standard Deviation: 201.92
# Q1:171.0  Q2:228.0  Q3:355.5  IQR:184.5  Q4:632.25
# Maximum: 2449.0  Minimum: 0.0  Average: 407.89  Standard Deviation: 241.29
# Q1:259.68  Q2:362.0  Q3:490.0  IQR:230.32  Q4:835.48
# Maximum: 2162.0  Minimum: 2.0  Average: 509.44  Standard Deviation: 268.46
# Q1:320.0  Q2:475.5  Q3:630.0  IQR:310.0  Q4:1095.0
# Maximum: 1422.0  Minimum: 0.0  Average: 146.4  Standard Deviation: 43.39
# ...

# %% [markdown]
# #Validation Data

# %%
csv_files = glob('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_df/' + '*.csv')
csv_files = sorted(csv_files, reverse=False)

for i in csv_files:
  globals()[i.split('/')[-1].split('.')[0]] = pd.read_csv(i)

# %%
dump_truck_object_size = list(validation_dump_truck_polygon_df['object size'])
cargo_truck_object_size = list(validation_cargo_truck_polygon_df['object size'])
truck_tractor_object_size = list(validation_truck_tractor_polygon_df['object size'])
tractor_object_size = list(validation_tractor_polygon_df['object size'])
excavator_object_size = list(validation_excavator_polygon_df['object size'])
trailer_object_size = list(validation_trailer_polygon_df['object size'])
van_object_size = list(validation_van_polygon_df['object size'])
small_car_object_size = list(validation_small_car_polygon_df['object size'])
bus_object_size = list(validation_bus_polygon_df['object size'])
other_vehicle_object_size = list(validation_other_vehicle_polygon_df['object size'])

average_dump_truck_object_size = np.mean(dump_truck_object_size)
average_cargo_truck_object_size = np.mean(cargo_truck_object_size)
average_truck_tractor_object_size = np.mean(truck_tractor_object_size)
average_tractor_object_size = np.mean(tractor_object_size)
average_excavator_object_size = np.mean(excavator_object_size)
average_trailer_object_size = np.mean(trailer_object_size)
average_van_object_size = np.mean(van_object_size)
average_small_car_object_size = np.mean(small_car_object_size)
average_bus_object_size = np.mean(bus_object_size)
average_other_vehicle_object_size = np.mean(other_vehicle_object_size)

vehicle_class_object_size_list = sum([dump_truck_object_size, cargo_truck_object_size, truck_tractor_object_size,
                                      tractor_object_size, excavator_object_size, trailer_object_size, van_object_size,
                                      small_car_object_size, bus_object_size, other_vehicle_object_size], [])

xs = ['Dump Truck', 'Cargo Truck', 'Truck Tractor', 'Tractor','Excavator',
      'Trailer', 'Van', 'Small Car', 'Bus', 'other-vehicle']
ys = [average_dump_truck_object_size, average_cargo_truck_object_size, average_truck_tractor_object_size,
      average_tractor_object_size, average_excavator_object_size, average_trailer_object_size,
      average_van_object_size, average_small_car_object_size, average_bus_object_size, average_other_vehicle_object_size]

plt.figure(figsize=(12, 4))
plt.title('Vehicle Average Object Size')
plt.xlabel('Class')
plt.ylabel('Count')
plt.bar(xs, ys, width=0.8, color='gray')
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_class_polygon_graph/validation_vehicle_average_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(vehicle_class_object_size_list), 2)}", end='  '); print(f"Minimum: {round(np.min(vehicle_class_object_size_list), 2)}", end='  ')
print(f"Average: {round(np.mean(vehicle_class_object_size_list), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(vehicle_class_object_size_list), 2)}")

percentile25 = np.percentile(vehicle_class_object_size_list, 25); percentile50 = np.percentile(vehicle_class_object_size_list, 50)
percentile75 = np.percentile(vehicle_class_object_size_list, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)


dump_truck_object_size = list(validation_dump_truck_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(dump_truck_object_size, range=(0,800), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(dump_truck_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Dump Truck Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_dump_truck_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(dump_truck_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(dump_truck_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(dump_truck_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(dump_truck_object_size), 2)}")

percentile25 = np.percentile(dump_truck_object_size, 25); percentile50 = np.percentile(dump_truck_object_size, 50)
percentile75 = np.percentile(dump_truck_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

cargo_truck_object_size = list(validation_cargo_truck_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(cargo_truck_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(cargo_truck_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Cargo Truck Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_cargo_truck_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(cargo_truck_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(cargo_truck_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(cargo_truck_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(cargo_truck_object_size), 2)}")

percentile25 = np.percentile(cargo_truck_object_size, 25); percentile50 = np.percentile(cargo_truck_object_size, 50)
percentile75 = np.percentile(cargo_truck_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

truck_tractor_object_size = list(validation_truck_tractor_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(truck_tractor_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(truck_tractor_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Truck Tractor Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_truck_tractor_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(truck_tractor_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(truck_tractor_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(truck_tractor_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(truck_tractor_object_size), 2)}")

percentile25 = np.percentile(truck_tractor_object_size, 25); percentile50 = np.percentile(truck_tractor_object_size, 50)
percentile75 = np.percentile(truck_tractor_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

tractor_object_size = list(validation_tractor_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(tractor_object_size, range=(0,1500), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(tractor_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Tractor Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_tractor_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(tractor_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(tractor_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(tractor_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(tractor_object_size), 2)}")

percentile25 = np.percentile(tractor_object_size, 25); percentile50 = np.percentile(tractor_object_size, 50)
percentile75 = np.percentile(tractor_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

excavator_object_size = list(validation_excavator_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(excavator_object_size, range=(0,2000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(excavator_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Excavator Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_excavator_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(excavator_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(excavator_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(excavator_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(excavator_object_size), 2)}")

percentile25 = np.percentile(excavator_object_size, 25); percentile50 = np.percentile(excavator_object_size, 50)
percentile75 = np.percentile(excavator_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

trailer_object_size = list(validation_trailer_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(trailer_object_size, range=(0,2000), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(trailer_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Trailer Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_trailer_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(trailer_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(trailer_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(trailer_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(trailer_object_size), 2)}")

percentile25 = np.percentile(trailer_object_size, 25); percentile50 = np.percentile(trailer_object_size, 50)
percentile75 = np.percentile(trailer_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

van_object_size = list(validation_van_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(van_object_size, range=(0,400), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(van_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Van Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_van_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(van_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(van_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(van_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(van_object_size), 2)}")

percentile25 = np.percentile(van_object_size, 25); percentile50 = np.percentile(van_object_size, 50)
percentile75 = np.percentile(van_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

small_car_object_size = list(validation_small_car_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(small_car_object_size, range=(0,400), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(small_car_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Small Car Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_small_car_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(small_car_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(small_car_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(small_car_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(small_car_object_size), 2)}")

percentile25 = np.percentile(small_car_object_size, 25); percentile50 = np.percentile(small_car_object_size, 50)
percentile75 = np.percentile(small_car_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

bus_object_size = list(validation_bus_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(bus_object_size, range=(0,1200), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(bus_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Bus Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_bus_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(bus_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(bus_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(bus_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(bus_object_size), 2)}")

percentile25 = np.percentile(bus_object_size, 25); percentile50 = np.percentile(bus_object_size, 50)
percentile75 = np.percentile(bus_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')

print("\n" * 3)

other_vehicle_object_size = list(validation_other_vehicle_polygon_df['object size'])

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(other_vehicle_object_size, range=(0,1600), color='gray')
plt.xlabel('Object Size')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
plt.boxplot(other_vehicle_object_size, showmeans=True)
plt.ylabel('Object Size')
plt.suptitle('Other Vehicle Object Size', size=20, verticalalignment='bottom')
plt.tight_layout(pad=3, w_pad=4)
plt.savefig('/content/drive/MyDrive/Aiffelthon/eda/object_size_distribution/validation_detailed_class_polygon_graph/validation_other_vehicle_polygon_graph.png',
            facecolor='#eeeeee', edgecolor='black', format='png', bbox_inches='tight')
plt.show()

print("\n")
print(f"Maximum: {round(np.max(other_vehicle_object_size), 2)}", end='  '); print(f"Minimum: {round(np.min(other_vehicle_object_size), 2)}", end='  ')
print(f"Average: {round(np.mean(other_vehicle_object_size), 2)}", end='  '); print(f"Standard Deviation: {round(np.std(other_vehicle_object_size), 2)}")

percentile25 = np.percentile(other_vehicle_object_size, 25); percentile50 = np.percentile(other_vehicle_object_size, 50)
percentile75 = np.percentile(other_vehicle_object_size, 75); percentileIQR = percentile75 - percentile25
percentileMAX = percentile75 + percentileIQR * 1.5

print(f"Q1:{round(percentile25, 2)}", end='  '); print(f"Q2:{round(percentile50, 2)}", end='  ')
print(f"Q3:{round(percentile75, 2)}", end='  '); print(f"IQR:{round(percentileIQR, 2)}", end='  ')
print(f"Q4:{round(percentileMAX, 2)}", end='  ')
# Out:
# Maximum: 11038.5  Minimum: 21.0  Average: 150.42  Standard Deviation: 90.21
# Q1:109.0  Q2:136.0  Q3:167.5  IQR:58.5  Q4:255.25
# Maximum: 998.0  Minimum: 48.0  Average: 203.96  Standard Deviation: 82.64
# Q1:154.0  Q2:191.0  Q3:234.0  IQR:80.0  Q4:354.0
# Maximum: 11038.5  Minimum: 32.0  Average: 293.53  Standard Deviation: 260.3
# Q1:155.0  Q2:243.0  Q3:381.5  IQR:226.5  Q4:721.25
# Maximum: 1184.5  Minimum: 75.0  Average: 331.69  Standard Deviation: 168.42
# Q1:219.5  Q2:311.0  Q3:420.0  IQR:200.5  Q4:720.75
# Maximum: 2605.0  Minimum: 187.5  Average: 527.41  Standard Deviation: 492.36
# Q1:273.0  Q2:351.0  Q3:480.0  IQR:207.0  Q4:790.5
# Maximum: 2071.5  Minimum: 80.5  Average: 406.32  Standard Deviation: 247.79
# Q1:253.5  Q2:344.5  Q3:527.0  IQR:273.5  Q4:937.25
# Maximum: 1299.5  Minimum: 42.0  Average: 481.72  Standard Deviation: 222.73
# Q1:317.0  Q2:504.0  Q3:632.0  IQR:315.0  Q4:1104.5
# Maximum: 1153.0  Minimum: 25.0  Average: 129.69  Standard Deviation: 42.22
# ...
